# %%
import pandas as pd
import numpy as np

# %%
prices = pd.read_csv('data/sample_prices.csv')

# %%
returns = prices.pct_change()
returns
# Out:
#         BLUE    ORANGE
# 0        NaN       NaN
# 1   0.023621  0.039662
# 2  -0.021807 -0.033638
# 3  -0.031763  0.082232
# 4   0.034477  0.044544
# 5   0.037786 -0.026381
# 6  -0.011452 -0.049187
# 7   0.032676  0.117008
# 8  -0.012581  0.067353
# 9   0.029581  0.078249
# 10  0.006151 -0.168261
# 11  0.012162  0.024041
# 12  0.021149 -0.055623

# %%
returns = returns.dropna()
returns
# Out:
#         BLUE    ORANGE
# 1   0.023621  0.039662
# 2  -0.021807 -0.033638
# 3  -0.031763  0.082232
# 4   0.034477  0.044544
# 5   0.037786 -0.026381
# 6  -0.011452 -0.049187
# 7   0.032676  0.117008
# 8  -0.012581  0.067353
# 9   0.029581  0.078249
# 10  0.006151 -0.168261
# 11  0.012162  0.024041
# 12  0.021149 -0.055623

# %%
returns.std()
# Out:
# BLUE      0.023977
# ORANGE    0.079601
# dtype: float64

# %%
deviations = returns - returns.mean()
sqr_dev = deviations**2
var = sqr_dev.mean()
vol = np.sqrt(var)
vol
# Out:
# BLUE      0.022957
# ORANGE    0.076212
# dtype: float64

# %%
var = sqr_dev.sum() / (returns.shape[0] - 1)
vol = np.sqrt(var)
vol
# Out:
# BLUE      0.023977
# ORANGE    0.079601
# dtype: float64

# %%
returns = pd.read_csv('data/Portfolios_Formed_on_ME_monthly_EW.csv',
                     header = 0, index_col = 0, parse_dates = True, na_values = -99.99)
returns
# Out:
# C:\Users\Yifei\AppData\Local\Temp\ipykernel_18776\98036668.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   returns = pd.read_csv('data/Portfolios_Formed_on_ME_monthly_EW.csv',
#         <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  Lo 10  \
# 192607   NaN  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33  -1.45
# 192608   NaN   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33   5.12
# 192609   NaN  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09   0.93
# 192610   NaN  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95  -4.84
# 192611   NaN  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16  -0.78
# ...      ...    ...     ...    ...    ...    ...    ...    ...    ...    ...
# 201808   NaN   3.47    4.04   2.87   3.09   5.05   3.90   3.54   2.49   2.41
# ...

# %%
columns = ['Lo 10', 'Hi 10']
returns = returns[columns]
returns.head()
# Out:
#         Lo 10  Hi 10
# 192607  -1.45   3.29
# 192608   5.12   3.70
# 192609   0.93   0.67
# 192610  -4.84  -2.43
# 192611  -0.78   2.70

# %%
returns = returns / 100
returns.head()
# Out:
#          Lo 10   Hi 10
# 192607 -0.0145  0.0329
# 192608  0.0512  0.0370
# 192609  0.0093  0.0067
# 192610 -0.0484 -0.0243
# 192611 -0.0078  0.0270

# %%
returns.columns = ['SmallCap', 'LargeCap']
returns.head()
# Out:
#         SmallCap  LargeCap
# 192607   -0.0145    0.0329
# 192608    0.0512    0.0370
# 192609    0.0093    0.0067
# 192610   -0.0484   -0.0243
# 192611   -0.0078    0.0270

# %%
returns.plot.line()
# Out:
# <Axes: >

# %%
returns.std()
# Out:
# SmallCap    0.106288
# LargeCap    0.053900
# dtype: float64

# %%
annualized_vol = returns.std()*np.sqrt(12)
annualized_vol
# Out:
# SmallCap    0.368193
# LargeCap    0.186716
# dtype: float64

# %%
n_months = returns.shape[0]

# %%
returns_per_month = (returns+1).prod()**(1/n_months) - 1
returns_per_month
# Out:
# SmallCap    0.012986
# LargeCap    0.007423
# dtype: float64

# %%
annualized_return = (returns_per_month+1)**12 - 1 
annualized_return
# Out:
# SmallCap    0.167463
# LargeCap    0.092810
# dtype: float64

# %%
annualized_return = (returns+1).prod()**(12/n_months) - 1
annualized_return
# Out:
# SmallCap    0.167463
# LargeCap    0.092810
# dtype: float64

# %%
annualized_return/annualized_vol
# Out:
# SmallCap    0.454825
# LargeCap    0.497063
# dtype: float64

# %%
rf_rate = 0.03

# %%
excess_ret = annualized_return - rf_rate
sharpe_ratio = excess_ret / annualized_vol
sharpe_ratio
# Out:
# SmallCap    0.373346
# LargeCap    0.336392
# dtype: float64
